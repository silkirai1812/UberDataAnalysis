# %%
import pandas as pd

# %%
data = pd.read_csv("data/UberData.csv")
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES          PURPOSE
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data.shape
# Out:
# (1156, 7)

# %%
data.columns
# Out:
# Index(['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES',
#        'PURPOSE'],
#       dtype='object')

# %%
data.tail()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                   STOP    MILES         PURPOSE
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
# dropping the last row
data.drop(1155, axis=0, inplace=True)

# %%
data.tail()
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES         PURPOSE
# 1150           Kar?chi    0.7         Meeting
# 1151  Unknown Location    3.9  Temporary Site
# 1152  Unknown Location   16.2         Meeting
# 1153           Gampaha    6.4  Temporary Site
# 1154         Ilukwatta   48.2  Temporary Site

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data.describe()
# Out:
#              MILES
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
# handling date columns

# %%
data["START_DATE"][0]
# Out:
# '01-01-2016 21:11'

# %%
data["START_DATE"] = pd.to_datetime(data["START_DATE"], format='mixed', dayfirst=False)

# %%
data.head()
# Out:
#            START_DATE          END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00  01-01-2016 21:17  Business  Fort Pierce
# 1 2016-01-02 01:25:00  01-02-2016 01:37  Business  Fort Pierce
# 2 2016-01-02 20:25:00  01-02-2016 20:38  Business  Fort Pierce
# 3 2016-01-05 17:31:00  01-05-2016 17:45  Business  Fort Pierce
# 4 2016-01-06 14:42:00  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE
# 0      Fort Pierce    5.1   Meal/Entertain
# 1      Fort Pierce    5.0              NaN
# 2      Fort Pierce    4.8  Errand/Supplies
# 3      Fort Pierce    4.7          Meeting
# 4  West Palm Beach   63.7   Customer Visit

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 63.3+ KB

# %%
data["END_DATE"] = pd.to_datetime(data["END_DATE"],format='mixed', dayfirst=False)

# %%
data
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# ...

# %%
ts=data["END_DATE"][0]

# %%
ts
# Out:
# Timestamp('2016-01-01 21:17:00')

# %%
ts.year
# Out:
# 2016

# %%
ts.month
# Out:
# 1

# %%
ts.day
# Out:
# 1

# %%
ts.month_name()
# Out:
# 'January'

# %%
ts.day_name()
# Out:
# 'Friday'

# %%
ts.dayofweek
# Out:
# 4

# %%
ts.hour
# Out:
# 21

# %%
ts.minute
# Out:
# 17

# %%
ts.second
# Out:
# 0

# %%
ts.minute
# Out:
# 17

# %%
# 23-01-2022
# "%dd-%mm-%yyyy"
# %d-%m-%y"

# %%
data["END_DATE"].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1150    2016
# 1151    2016
# 1152    2016
# 1153    2016
# 1154    2016
# Name: END_DATE, Length: 1155, dtype: int32

# %%
ts
# Out:
# Timestamp('2016-01-01 21:17:00')

# %%
data["END_DATE"].dt.hour
# Out:
# 0       21
# 1        1
# 2       20
# 3       17
# 4       15
#         ..
# 1150     1
# 1151    13
# 1152    15
# 1153    21
# 1154    23
# Name: END_DATE, Length: 1155, dtype: int32

# %%
data["END_DATE"].dt.year
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1150    2016
# 1151    2016
# 1152    2016
# 1153    2016
# 1154    2016
# Name: END_DATE, Length: 1155, dtype: int32

# %%
data["END_YEAR"]=data["END_DATE"].dt.year
# number of years=1

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  END_YEAR
# 0      Fort Pierce    5.1   Meal/Entertain      2016
# 1      Fort Pierce    5.0              NaN      2016
# 2      Fort Pierce    4.8  Errand/Supplies      2016
# 3      Fort Pierce    4.7          Meeting      2016
# 4  West Palm Beach   63.7   Customer Visit      2016

# %%
data.describe()
# Out:
#                           START_DATE                       END_DATE  \
# count                           1155                           1155
# mean   2016-07-16 23:44:33.402597376  2016-07-17 00:07:47.999999744
# min              2016-01-01 21:11:00            2016-01-01 21:17:00
# 25%              2016-04-01 02:10:00            2016-04-01 02:35:00
# 50%              2016-07-21 17:17:00            2016-07-21 17:23:00
# 75%              2016-10-27 21:06:30            2016-10-27 21:21:00
# max              2016-12-31 22:08:00            2016-12-31 23:51:00
# std                              NaN                            NaN
#
#              MILES  END_YEAR
# count  1155.000000    1155.0
# mean     10.566840    2016.0
# min       0.500000    2016.0
# 25%       2.900000    2016.0
# 50%       6.000000    2016.0
# 75%      10.400000    2016.0
# max     310.300000    2016.0
# std      21.579106       0.0

# %%
data['MILES'].sum()
# Out:
# 12204.7

# %%
# count of rides per month
data['MONTH']=data['START_DATE'].dt.month_name()

# %%
data['MONTH'].value_counts()
# Out:
# MONTH
# December     146
# August       133
# November     122
# February     115
# March        113
# July         112
# June         108
# October      106
# January       61
# April         54
# May           49
# September     36
# Name: count, dtype: int64

# %%
# how many rides were of at least 5 miles?
data[data['MILES']>=5].count()
# Out:
# START_DATE    659
# END_DATE      659
# CATEGORY      659
# START         659
# STOP          659
# MILES         659
# PURPOSE       407
# END_YEAR      659
# MONTH         659
# dtype: int64

# %%
data['MILES']>=5
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1150    False
# 1151    False
# 1152     True
# 1153     True
# 1154     True
# Name: MILES, Length: 1155, dtype: bool

# %%
sum(data['MILES']>=5)
# Out:
# 659

# %%
# create a new column for km, 1mile = 1.609 kms

# %%
data['KILOMETERS']=data['MILES']*1.609

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  END_YEAR    MONTH  KILOMETERS
# 0      Fort Pierce    5.1   Meal/Entertain      2016  January      8.2059
# 1      Fort Pierce    5.0              NaN      2016  January      8.0450
# 2      Fort Pierce    4.8  Errand/Supplies      2016  January      7.7232
# 3      Fort Pierce    4.7          Meeting      2016  January      7.5623
# 4  West Palm Beach   63.7   Customer Visit      2016  January    102.4933

# %%
# average miles driven per month

# %%
data.groupby('MONTH')['MILES'].mean()
# Out:
# MONTH
# April        20.611111
# August       10.041353
# December      6.721233
# February      7.897391
# January       8.408197
# July         10.933929
# June          7.803704
# March        14.990265
# May           7.424490
# November      6.695902
# October      17.075472
# September    16.716667
# Name: MILES, dtype: float64

# %%
data["PURPOSE"].value_counts(dropna=False)
# Out:
# PURPOSE
# NaN                502
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: count, dtype: int64

# %%
#  dealing with nan values

# remove? NO
# forwardfill or backwardfill? No (No relation with data)
# replace - mean ? NA
# replace - median ? NA
# replace - mode? may not be the best way but can do

# %%
# make it another category - "undisclosed"? yes
# "impute" using other features, START, STOP, MILES, CATEGORY, DATE - Yes
